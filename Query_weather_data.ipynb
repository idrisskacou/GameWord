# %%
import psycopg2
import random
import datetime

# %%
# PostgreSQL database connection details
conn = psycopg2.connect(
    dbname="mathphysic",
    user="postgres",
    password="1234",
    host="localhost",
    port="5432"
)

# %%
cur = conn.cursor()

# %%
query = """
        SELECT * FROM launch_weather LIMIT 3
"""

# %%
# Execute creation of table the SQL statement 
cur.execute(query)
conn.commit()
data = cur.fetchall()

# %%
for row in data:
    print(data)
# Out:
# [(1, 'df688cbc-6dfc-4202-8b5a-9aac1f1ae5a4', datetime.datetime(2025, 6, 8, 0, 0), 16.8, 16.4, 'SW', 50, 'rain', 3.6, 4.2, 12.3, 23.6, 33.4, 'E', 'N', 'N', 9.1, -33.4, -43.1, 57, 87, 42, 1084, 749, 149, 'high', 'high', 'high', 1298.8, 5, 'moderate', 3.2, 84, 26.6, 8.2, 2.6, 8.6, 78, 23.3, 0.0, 'NE', 2.2, 'S', 25.0, 39.8, 7.6, 8.1, 12.1, 5.8, 20.9, 35.0, -16.9, -38.5, 21.7, 11, 33.1, 'moderate'), (2, 'b3d65e1a-2fc2-4a63-bc81-c8298f4aacaf', datetime.datetime(2025, 7, 3, 0, 0), 15.6, 47.7, 'S', 20, 'none', 36.3, 13.3, 7.5, 30.7, 47.1, 'NW', 'SE', 'E', 4.9, -37.3, -52.2, 93, 56, 13, 1095, 760, 125, 'low', 'low', 'high', 1205.7, 6, 'moderate', 2.6, 63, 72.7, 7.5, 11.1, 9.4, 80, 19.0, 6.0, 'N', 1.2, 'W', 1.1, 92.1, 2.3, 67.9, 5.2, 1.0, 18.6, 30.5, -0.3, -20.0, 4.2, 62, 24.2, 'moderate'), (3, '366086ee-749d-4005-8dad-5e7bb7fa0960', datetime.datetime(2024, 10, 22, 0, 0), 31.9, 34.5, 'NW', 72, 'none', 16.8, 10.3, 47.6, 8.5, 20.9, 'NE', 'S', 'N', -6.9, -42.4, -67.4, 24, 55, 79, 1029, 650, 102, 
# ...
