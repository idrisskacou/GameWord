# %%
import psycopg2
import random
import datetime

# %%
# PostgreSQL database connection details
conn = psycopg2.connect(
    dbname="mathphysic",
    user="postgres",
    password="1234",
    host="localhost",
    port="5432"
)

# %%
cur = conn.cursor()

# %%
# SQL statement to create the table
create_table_query = """
CREATE TABLE IF NOT EXISTS launch_weather (
    id SERIAL PRIMARY KEY,
    timestamp TIMESTAMP NOT NULL,
    surface_temperature FLOAT,
    surface_wind_speed FLOAT,
    surface_wind_direction VARCHAR(2),
    surface_humidity INTEGER,
    precipitation_type VARCHAR(10),
    precipitation_intensity FLOAT,
    visibility FLOAT,
    upper_wind_speed_0_1km FLOAT,
    upper_wind_speed_1_5km FLOAT,
    upper_wind_speed_5_10km FLOAT,
    upper_wind_direction_0_1km VARCHAR(2),
    upper_wind_direction_1_5km VARCHAR(2),
    upper_wind_direction_5_10km VARCHAR(2),
    temperature_profile_0_1km FLOAT,
    temperature_profile_1_5km FLOAT,
    temperature_profile_5_10km FLOAT,
    humidity_profile_0_1km INTEGER,
    humidity_profile_1_5km INTEGER,
    humidity_profile_5_10km INTEGER,
    pressure_profile_0_1km INTEGER,
    pressure_profile_1_5km INTEGER,
    pressure_profile_5_10km INTEGER,
    turbulence_level_0_1km VARCHAR(10),
    turbulence_level_1_5km VARCHAR(10),
    turbulence_level_5_10km VARCHAR(10),
    solar_radiation_levels FLOAT,
    geomagnetic_activity INTEGER,
    solar_flare_activity VARCHAR(10),
    cosmic_ray_intensity FLOAT,
    lightning_frequency INTEGER,
    lightning_proximity FLOAT,
    cloud_base_altitude FLOAT,
    cloud_top_altitude FLOAT,
    cloud_thickness FLOAT,
    cloud_coverage_percentage INTEGER,
    sea_surface_temperature FLOAT,
    wave_height FLOAT,
    wave_direction VARCHAR(2),
    current_speed FLOAT,
    current_direction VARCHAR(2),
    pm2_5 FLOAT,
    pm10 FLOAT,
    co FLOAT,
    o3 FLOAT,
    no2 FLOAT,
    so2 FLOAT,
    ground_temperature FLOAT,
    air_temperature_0_1km FLOAT,
    air_temperature_1_5km FLOAT,
    air_temperature_5_10km FLOAT,
    dew_point FLOAT,
    ground_moisture_level INTEGER,
    soil_temperature FLOAT,
    fog_presence_and_density VARCHAR(20)
);
"""

# %%
# Execute the SQL statement
cur.execute(create_table_query)
conn.commit()

# %%
# Function to generate random data for a given field
def generate_random_data(base_date):
    days_offset = random.randint(-3, 3)  # Randomly select days between -3 and 3
    random_timestamp = base_date + datetime.timedelta(days=days_offset)
    data = {
        "timestamp": random_timestamp,
        "weather_conditions": {
            "surface_temperature": round(random.uniform(15.0, 35.0), 1),
            "surface_wind_speed": round(random.uniform(0.0, 50.0), 1),
            "surface_wind_direction": random.choice(["N", "NE", "E", "SE", "S", "SW", "W", "NW"]),
            "surface_humidity": random.randint(20, 100),
            "precipitation_type": random.choice(["none", "rain", "snow"]),
            "precipitation_intensity": round(random.uniform(0.0, 50.0), 1),
            "visibility": round(random.uniform(1.0, 20.0), 1)
        },
        "upper_atmosphere_conditions": {
            "upper_wind_speeds": {
                "0-1km": round(random.uniform(0.0, 50.0), 1),
                "1-5km": round(random.uniform(0.0, 50.0), 1),
                "5-10km": round(random.uniform(0.0, 50.0), 1)
            },
            "upper_wind_directions": {
                "0-1km": random.choice(["N", "NE", "E", "SE", "S", "SW", "W", "NW"]),
                "1-5km": random.choice(["N", "NE", "E", "SE", "S", "SW", "W", "NW"]),
                "5-10km": random.choice(["N", "NE", "E", "SE", "S", "SW", "W", "NW"])
            },
            "temperature_profiles": {
                "0-1km": round(random.uniform(-20.0, 20.0), 1),
                "1-5km": round(random.uniform(-60.0, 0.0), 1),
                "5-10km": round(random.uniform(-70.0, -10.0), 1)
            },
            "humidity_profiles": {
                "0-1km": random.randint(10, 100),
                "1-5km": random.randint(10, 100),
                "5-10km": random.randint(10, 100)
            },
            "pressure_profiles": {
                "0-1km": random.randint(900, 1100),
                "1-5km": random.randint(400, 900),
                "5-10km": random.randint(100, 400)
            },
            "turbulence_levels": {
                "0-1km": random.choice(["low", "medium", "high"]),
                "1-5km": random.choice(["low", "medium", "high"]),
                "5-10km": random.choice(["low", "medium", "high"])
            }
        },
        "solar_activity": {
            "solar_radiation_levels": round(random.uniform(1200, 1400), 1),
            "geomagnetic_activity": random.randint(0, 9),
            "solar_flare_activity": random.choice(["none", "low", "moderate", "high"]),
            "cosmic_ray_intensity": round(random.uniform(2.0, 6.0), 1)
        },
        "lightning_activity": {
            "lightning_frequency": random.randint(0, 100),
            "lightning_proximity": round(random.uniform(0.0, 100.0), 1)
        },
        "cloud_cover": {
            "cloud_base_altitude": round(random.uniform(0.5, 10.0), 1),
            "cloud_top_altitude": round(random.uniform(1.0, 15.0), 1),
            "cloud_thickness": round(random.uniform(0.1, 15.0), 1),
            "cloud_coverage_percentage": random.randint(0, 100)
        },
        "marine_conditions": {
            "sea_surface_temperature": round(random.uniform(15.0, 30.0), 1),
            "wave_height": round(random.uniform(0.0, 10.0), 1),
            "wave_direction": random.choice(["N", "NE", "E", "SE", "S", "SW", "W", "NW"]),
            "current_speed": round(random.uniform(0.0, 3.0), 1),
            "current_direction": random.choice(["N", "NE", "E", "SE", "S", "SW", "W", "NW"])
        },
        "air_quality": {
            "pm2_5": round(random.uniform(0.0, 50.0), 1),
            "pm10": round(random.uniform(0.0, 100.0), 1),
            "co": round(random.uniform(0.0, 10.0), 1),
            "o3": round(random.uniform(0.0, 100.0), 1),
            "no2": round(random.uniform(0.0, 50.0), 1),
            "so2": round(random.uniform(0.0, 20.0), 1)
        },
        "thermal_conditions": {
            "ground_temperature": round(random.uniform(15.0, 35.0), 1),
            "air_temperature_at_different_altitudes": {
                "0-1km": round(random.uniform(15.0, 35.0), 1),
                "1-5km": round(random.uniform(-20.0, 0.0), 1),
                "5-10km": round(random.uniform(-70.0, -10.0), 1)
            },
            "dew_point": round(random.uniform(0.0, 25.0), 1)
        },
        "launch_site_specific_conditions": {
            "ground_moisture_level": random.randint(0, 100),
            "soil_temperature": round(random.uniform(15.0, 35.0), 1),
            "fog_presence_and_density": random.choice(["none", "light", "moderate", "dense"])
        }
    }
    return data

# %%
# Function to insert generated data into the database
def insert_data(data, timestamp):
    query = """
    INSERT INTO launch_weather (
        timestamp,
        surface_temperature,
        surface_wind_speed,
        surface_wind_direction,
        surface_humidity,
        precipitation_type,
        precipitation_intensity,
        visibility,
        upper_wind_speed_0_1km,
        upper_wind_speed_1_5km,
        upper_wind_speed_5_10km,
        upper_wind_direction_0_1km,
        upper_wind_direction_1_5km,
        upper_wind_direction_5_10km,
        temperature_profile_0_1km,
        temperature_profile_1_5km,
        temperature_profile_5_10km,
        humidity_profile_0_1km,
        humidity_profile_1_5km,
        humidity_profile_5_10km,
        pressure_profile_0_1km,
        pressure_profile_1_5km,
        pressure_profile_5_10km,
        turbulence_level_0_1km,
        turbulence_level_1_5km,
        turbulence_level_5_10km,
        solar_radiation_levels,
        geomagnetic_activity,
        solar_flare_activity,
        cosmic_ray_intensity,
        lightning_frequency,
        lightning_proximity,
        cloud_base_altitude,
        cloud_top_altitude,
        cloud_thickness,
        cloud_coverage_percentage,
        sea_surface_temperature,
        wave_height,
        wave_direction,
        current_speed,
        current_direction,
        pm2_5,
        pm10,
        co,
        o3,
        no2,
        so2,
        ground_temperature,
        air_temperature_0_1km,
        air_temperature_1_5km,
        air_temperature_5_10km,
        dew_point,
        ground_moisture_level,
        soil_temperature,
        fog_presence_and_density
    ) VALUES (
        # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s
    )
    """
    values = (
        timestamp,
        data["weather_conditions"]["surface_temperature"],
        data["weather_conditions"]["surface_wind_speed"],
        data["weather_conditions"]["surface_wind_direction"],
        data["weather_conditions"]["surface_humidity"],
        data["weather_conditions"]["precipitation_type"],
        data["weather_conditions"]["precipitation_intensity"],
        data["weather_conditions"]["visibility"],
        data["upper_atmosphere_conditions"]["upper_wind_speeds"]["0-1km"],
        data["upper_atmosphere_conditions"]["upper_wind_speeds"]["1-5km"],
        data["upper_atmosphere_conditions"]["upper_wind_speeds"]["5-10km"],
        data["upper_atmosphere_conditions"]["upper_wind_directions"]["0-1km"],
        data["upper_atmosphere_conditions"]["upper_wind_directions"]["1-5km"],
        data["upper_atmosphere_conditions"]["upper_wind_directions"]["5-10km"],
        data["upper_atmosphere_conditions"]["temperature_profiles"]["0-1km"],
        data["upper_atmosphere_conditions"]["temperature_profiles"]["1-5km"],
        data["upper_atmosphere_conditions"]["temperature_profiles"]["5-10km"],
        data["upper_atmosphere_conditions"]["humidity_profiles"]["0-1km"],
        data["upper_atmosphere_conditions"]["humidity_profiles"]["1-5km"],
        data["upper_atmosphere_conditions"]["humidity_profiles"]["5-10km"],
        data["upper_atmosphere_conditions"]["pressure_profiles"]["0-1km"],
        data["upper_atmosphere_conditions"]["pressure_profiles"]["1-5km"],
        data["upper_atmosphere_conditions"]["pressure_profiles"]["5-10km"],
        data["upper_atmosphere_conditions"]["turbulence_levels"]["0-1km"],
        data["upper_atmosphere_conditions"]["turbulence_levels"]["1-5km"],
        data["upper_atmosphere_conditions"]["turbulence_levels"]["5-10km"],
        data["solar_activity"]["solar_radiation_levels"],
        data["solar_activity"]["geomagnetic_activity"],
        data["solar_activity"]["solar_flare_activity"],
        data["solar_activity"]["cosmic_ray_intensity"],
        data["lightning_activity"]["lightning_frequency"],
        data["lightning_activity"]["lightning_proximity"],
        data["cloud_cover"]["cloud_base_altitude"],
        data["cloud_cover"]["cloud_top_altitude"],
        data["cloud_cover"]["cloud_thickness"],
        data["cloud_cover"]["cloud_coverage_percentage"],
        data["marine_conditions"]["sea_surface_temperature"],
        data["marine_conditions"]["wave_height"],
        data["marine_conditions"]["wave_direction"],
        data["marine_conditions"]["current_speed"],
        data["marine_conditions"]["current_direction"],
        data["air_quality"]["pm2_5"],
        data["air_quality"]["pm10"],
        data["air_quality"]["co"],
        data["air_quality"]["o3"],
        data["air_quality"]["no2"],
        data["air_quality"]["so2"],
        data["thermal_conditions"]["ground_temperature"],
        data["thermal_conditions"]["air_temperature_at_different_altitudes"]["0-1km"],
        data["thermal_conditions"]["air_temperature_at_different_altitudes"]["1-5km"],
        data["thermal_conditions"]["air_temperature_at_different_altitudes"]["5-10km"],
        data["thermal_conditions"]["dew_point"],
        data["launch_site_specific_conditions"]["ground_moisture_level"],
        data["launch_site_specific_conditions"]["soil_temperature"],
        data["launch_site_specific_conditions"]["fog_presence_and_density"]
    )
    cur.execute(query, values)
    # conn.commit()

# %%
# Function to check if launch keys are generated
def get_generated_launch_keys():
    query = "SELECT id FROM launch WHERE is_generated = TRUE"
    cur.execute(query)
    return cur.fetchall()

# %%
# Retrieve all IDs from the launch table
cur.execute("SELECT id FROM launch")
launch_ids = cur.fetchall()
base_date = datetime.datetime(2023, 7, 1)
# Generate and insert data for each ID
for (id,) in launch_ids:
    weather_data = generate_random_data(base_date)
    insert_data(id, weather_data)

# Commit the transaction and close the connection
conn.commit()
cur.close()
conn.close()

# %%
# create_table_query = """
# CREATE TABLE IF NOT EXISTS launch_weather (
#     id SERIAL PRIMARY KEY,
#     launch_id UUID REFERENCES launch(id),
#     timestamp TIMESTAMP NOT NULL,
#     surface_temperature FLOAT,
#     surface_wind_speed FLOAT,
#     surface_wind_direction VARCHAR(2),
#     surface_humidity INTEGER,
#     precipitation_type VARCHAR(10),
#     precipitation_intensity FLOAT,
#     visibility FLOAT,
#     upper_wind_speed_0_1km FLOAT,
#     upper_wind_speed_1_5km FLOAT,
#     upper_wind_speed_5_10km FLOAT,
#     upper_wind_direction_0_1km VARCHAR(2),
#     upper_wind_direction_1_5km VARCHAR(2),
#     upper_wind_direction_5_10km VARCHAR(2),
#     temperature_profile_0_1km FLOAT,
#     temperature_profile_1_5km FLOAT,
#     temperature_profile_5_10km FLOAT,
#     humidity_profile_0_1km INTEGER,
#     humidity_profile_1_5km INTEGER,
#     humidity_profile_5_10km INTEGER,
#     pressure_profile_0_1km INTEGER,
#     pressure_profile_1_5km INTEGER,
#     pressure_profile_5_10km INTEGER,
#     turbulence_level_0_1km VARCHAR(10),
#     turbulence_level_1_5km VARCHAR(10),
#     turbulence_level_5_10km VARCHAR(10),
#     solar_radiation_levels FLOAT,
#     geomagnetic_activity INTEGER,
#     solar_flare_activity VARCHAR(10),
#     cosmic_ray_intensity FLOAT,
#     lightning_frequency INTEGER,
#     lightning_proximity FLOAT,
#     cloud_base_altitude FLOAT,
#     cloud_top_altitude FLOAT,
#     cloud_thickness FLOAT,
#     cloud_coverage_percentage INTEGER,
#     sea_surface_temperature FLOAT,
#     wave_height FLOAT,
#     wave_direction VARCHAR(2),
#     current_speed FLOAT,
#     current_direction VARCHAR(2),
#     pm2_5 FLOAT,
#     pm10 FLOAT,
#     co FLOAT,
#     o3 FLOAT,
#     no2 FLOAT,
#     so2 FLOAT,
#     ground_temperature FLOAT,
#     air_temperature_0_1km FLOAT,
#     air_temperature_1_5km FLOAT,
#     air_temperature_5_10km FLOAT,
#     dew_point FLOAT,
#     ground_moisture_level INTEGER,
#     soil_temperature FLOAT,
#     fog_presence_and_density VARCHAR(20)
# );
# """

# %%
# # Function to generate random data for a given field
# def generate_random_data():
#     data = {
#         "timestamp": random.uniform(datetime),
#         "weather_conditions": {
#             "surface_temperature": round(random.uniform(15.0, 35.0), 1),
#             "surface_wind_speed": round(random.uniform(0.0, 50.0), 1),
#             "surface_wind_direction": random.choice(["N", "NE", "E", "SE", "S", "SW", "W", "NW"]),
#             "surface_humidity": random.randint(20, 100),
#             "precipitation_type": random.choice(["none", "rain", "snow"]),
#             "precipitation_intensity": round(random.uniform(0.0, 50.0), 1),
#             "visibility": round(random.uniform(1.0, 20.0), 1)
#         },
#         "upper_atmosphere_conditions": {
#             "upper_wind_speeds": {
#                 "0-1km": round(random.uniform(0.0, 50.0), 1),
#                 "1-5km": round(random.uniform(0.0, 50.0), 1),
#                 "5-10km": round(random.uniform(0.0, 50.0), 1)
#             },
#             "upper_wind_directions": {
#                 "0-1km": random.choice(["N", "NE", "E", "SE", "S", "SW", "W", "NW"]),
#                 "1-5km": random.choice(["N", "NE", "E", "SE", "S", "SW", "W", "NW"]),
#                 "5-10km": random.choice(["N", "NE", "E", "SE", "S", "SW", "W", "NW"])
#             },
#             "temperature_profiles": {
#                 "0-1km": round(random.uniform(-20.0, 20.0), 1),
#                 "1-5km": round(random.uniform(-60.0, 0.0), 1),
#                 "5-10km": round(random.uniform(-70.0, -10.0), 1)
#             },
#             "humidity_profiles": {
#                 "0-1km": random.randint(10, 100),
#                 "1-5km": random.randint(10, 100),
#                 "5-10km": random.randint(10, 100)
#             },
#             "pressure_profiles": {
#                 "0-1km": random.randint(900, 1100),
#                 "1-5km": random.randint(400, 900),
#                 "5-10km": random.randint(100, 400)
#             },
#             "turbulence_levels": {
#                 "0-1km": random.choice(["low", "medium", "high"]),
#                 "1-5km": random.choice(["low", "medium", "high"]),
#                 "5-10km": random.choice(["low", "medium", "high"])
#             }
#         },
#         "solar_activity": {
#             "solar_radiation_levels": round(random.uniform(1200, 1400), 1),
#             "geomagnetic_activity": random.randint(0, 9),
#             "solar_flare_activity": random.choice(["none", "low", "moderate", "high"]),
#             "cosmic_ray_intensity": round(random.uniform(2.0, 6.0), 1)
#         },
#         "lightning_activity": {
#             "lightning_frequency": random.randint(0, 100),
#             "lightning_proximity": round(random.uniform(0.0, 100.0), 1)
#         },
#         "cloud_cover": {
#             "cloud_base_altitude": round(random.uniform(0.5, 10.0), 1),
#             "cloud_top_altitude": round(random.uniform(1.0, 15.0), 1),
#             "cloud_thickness": round(random.uniform(0.1, 15.0), 1),
#             "cloud_coverage_percentage": random.randint(0, 100)
#         },
#         "marine_conditions": {
#             "sea_surface_temperature": round(random.uniform(15.0, 30.0), 1),
#             "wave_height": round(random.uniform(0.0, 10.0), 1),
#             "wave_direction": random.choice(["N", "NE", "E", "SE", "S", "SW", "W", "NW"]),
#             "current_speed": round(random.uniform(0.0, 3.0), 1),
#             "current_direction": random.choice(["N", "NE", "E", "SE", "S", "SW", "W", "NW"])
#         },
#         "air_quality": {
#             "pm2_5": round(random.uniform(0.0, 50.0), 1),
#             "pm10": round(random.uniform(0.0, 100.0), 1),
#             "co": round(random.uniform(0.0, 10.0), 1),
#             "o3": round(random.uniform(0.0, 100.0), 1),
#             "no2": round(random.uniform(0.0, 50.0), 1),
#             "so2": round(random.uniform(0.0, 20.0), 1)
#         },
#         "thermal_conditions": {
#             "ground_temperature": round(random.uniform(15.0, 35.0), 1),
#             "air_temperature_at_different_altitudes": {
#                 "0-1km": round(random.uniform(15.0, 35.0), 1),
#                 "1-5km": round(random.uniform(-20.0, 0.0), 1),
#                 "5-10km": round(random.uniform(-70.0, -10.0), 1)
#             },
#             "dew_point": round(random.uniform(0.0, 25.0), 1)
#         },
#         "launch_site_specific_conditions": {
#             "ground_moisture_level": random.randint(0, 100),
#             "soil_temperature": round(random.uniform(15.0, 35.0), 1),
#             "fog_presence_and_density": random.choice(["none", "light", "moderate", "dense"])
#         }
#     }
#     return data

# %%
# # Function to insert generated data into the database
# def insert_data(data, timestamp, launch_id):
#     query = """
#     INSERT INTO launch_weather (
#         timestamp,
#         launch_id,
#         surface_temperature,
#         surface_wind_speed,
#         surface_wind_direction,
#         surface_humidity,
#         precipitation_type,
#         precipitation_intensity,
#         visibility,
#         upper_wind_speed_0_1km,
#         upper_wind_speed_1_5km,
#         upper_wind_speed_5_10km,
#         upper_wind_direction_0_1km,
#         upper_wind_direction_1_5km,
#         upper_wind_direction_5_10km,
#         temperature_profile_0_1km,
#         temperature_profile_1_5km,
#         temperature_profile_5_10km,
#         humidity_profile_0_1km,
#         humidity_profile_1_5km,
#         humidity_profile_5_10km,
#         pressure_profile_0_1km,
#         pressure_profile_1_5km,
#         pressure_profile_5_10km,
#         turbulence_level_0_1km,
#         turbulence_level_1_5km,
#         turbulence_level_5_10km,
#         solar_radiation_levels,
#         geomagnetic_activity,
#         solar_flare_activity,
#         cosmic_ray_intensity,
#         lightning_frequency,
#         lightning_proximity,
#         cloud_base_altitude,
#         cloud_top_altitude,
#         cloud_thickness,
#         cloud_coverage_percentage,
#         sea_surface_temperature,
#         wave_height,
#         wave_direction,
#         current_speed,
#         current_direction,
#         pm2_5,
#         pm10,
#         co,
#         o3,
#         no2,
#         so2,
#         ground_temperature,
#         air_temperature_0_1km,
#         air_temperature_1_5km,
#         air_temperature_5_10km,
#         dew_point,
#         ground_moisture_level,
#         soil_temperature,
#         fog_presence_and_density
#     ) VALUES (
#         %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s
#     )
#     """
#     # values = (
#     #     timestamp,
#     #     id,
#     #     data["weather_conditions"]["surface_temperature"],
#     #     data["weather_conditions"]["surface_wind_speed"],
#     #     data["weather_conditions"]["surface_wind_direction"],
#     #     data["weather_conditions"]["surface_humidity"],
#     #     data["weather_conditions"]["precipitation_type"],
#     #     data["weather_conditions"]["precipitation_intensity"],
#     #     data["weather_conditions"]["visibility"],
#     #     data["upper_atmosphere_conditions"]["upper_wind_speeds"]["0-1km"],
#     #     data["upper_atmosphere_conditions"]["upper_wind_speeds"]["1-5km"],
#     #     data["upper_atmosphere_conditions"]["upper_wind_speeds"]["5-10km"],
#     #     data["upper_atmosphere_conditions"]["upper_wind_directions"]["0-1km"],
#     #     data["upper_atmosphere_conditions"]["upper_wind_directions"]["1-5km"],
#     #     data["upper_atmosphere_conditions"]["upper_wind_directions"]["5-10km"],
#     #     data["upper_atmosphere_conditions"]["temperature_profiles"]["0-1km"],
#     #     data["upper_atmosphere_conditions"]["temperature_profiles"]["1-5km"],
#     #     data["upper_atmosphere_conditions"]["temperature_profiles"]["5-10km"],
#     #     data["upper_atmosphere_conditions"]["humidity_profiles"]["0-1km"],
#     #     data["upper_atmosphere_conditions"]["humidity_profiles"]["1-5km"],
#     #     data["upper_atmosphere_conditions"]["humidity_profiles"]["5-10km"],
#     #     data["upper_atmosphere_conditions"]["pressure_profiles"]["0-1km"],
#     #     data["upper_atmosphere_conditions"]["pressure_profiles"]["1-5km"],
#     #     data["upper_atmosphere_conditions"]["pressure_profiles"]["5-10km"],
#     #     data["upper_atmosphere_conditions"]["turbulence_levels"]["0-1km"],
#     #     data["upper_atmosphere_conditions"]["turbulence_levels"]["1-5km"],
#     #     data["upper_atmosphere_conditions"]["turbulence_levels"]["5-10km"],
#     #     data["solar_activity"]["solar_radiation_levels"],
#     #     data["solar_activity"]["geomagnetic_activity"],
#     #     data["solar_activity"]["solar_flare_activity"],
#     #     data["solar_activity"]["cosmic_ray_intensity"],
#     #     data["lightning_activity"]["lightning_frequency"],
#     #     data["lightning_activity"]["lightning_proximity"],
#     #     data["cloud_cover"]["cloud_base_altitude"],
#     #     data["cloud_cover"]["cloud_top_altitude"],
#     #     data["cloud_cover"]["cloud_thickness"],
#     #     data["cloud_cover"]["cloud_coverage_percentage"],
#     #     data["marine_conditions"]["sea_surface_temperature"],
#     #     data["marine_conditions"]["wave_height"],
#     #     data["marine_conditions"]["wave_direction"],
#     #     data["marine_conditions"]["current_speed"],
#     #     data["marine_conditions"]["current_direction"],
#     #     data["air_quality"]["pm2_5"],
#     #     data["air_quality"]["pm10"],
#     #     data["air_quality"]["co"],
#     #     data["air_quality"]["o3"],
#     #     data["air_quality"]["no2"],
#     #     data["air_quality"]["so2"],
#     #     data["thermal_conditions"]["ground_temperature"],
#     #     data["thermal_conditions"]["air_temperature_at_different_altitudes"]["0-1km"],
#     #     data["thermal_conditions"]["air_temperature_at_different_altitudes"]["1-5km"],
#     #     data["thermal_conditions"]["air_temperature_at_different_altitudes"]["5-10km"],
#     #     data["thermal_conditions"]["dew_point"],
#     #     data["launch_site_specific_conditions"]["ground_moisture_level"],
#     #     data["launch_site_specific_conditions"]["soil_temperature"],
#     #     data["launch_site_specific_conditions"]["fog_presence_and_density"]
#     # )
#     # cur.execute(query, values)
#     # conn.commit()



#     values = (
#         id,
#         data["surface_temperature"],
#         data["surface_wind_speed"],
#         data["surface_wind_direction"],
#         data["surface_humidity"],
#         data["precipitation_type"],
#         data["precipitation_intensity"],
#         data["visibility"],
#         data["upper_wind_speed_0_1km"],
#         data["upper_wind_speed_1_5km"],
#         data["upper_wind_speed_5_10km"],
#         data["upper_wind_direction_0_1km"],
#         data["upper_wind_direction_1_5km"],
#         data["upper_wind_direction_5_10km"],
#         data["temperature_profile_0_1km"],
#         data["temperature_profile_1_5km"],
#         data["temperature_profile_5_10km"],
#         data["humidity_profile_0_1km"],
#         data["humidity_profile_1_5km"],
#         data["humidity_profile_5_10km"],
#         data["pressure_profile_0_1km"],
#         data["pressure_profile_1_5km"],
#         data["pressure_profile_5_10km"],
#         data["turbulence_level_0_1km"],
#         data["turbulence_level_1_5km"],
#         data["turbulence_level_5_10km"],
#         data["solar_radiation_levels"],
#         data["geomagnetic_activity"],
#         data["solar_flare_activity"],
#         data["cosmic_ray_intensity"],
#         data["lightning_frequency"],
#         data["lightning_proximity"],
#         data["cloud_base_altitude"],
#         data["cloud_top_altitude"],
#         data["cloud_thickness"],
#         data["cloud_coverage_percentage"],
#         data["sea_surface_temperature"],
#         data["wave_height"],
#         data["wave_direction"],
#         data["current_speed"],
#         data["current_direction"],
#         data["pm2_5"],
#         data["pm10"],
#         data["co"],
#         data["o3"],
#         data["no2"],
#         data["so2"],
#         data["ground_temperature"],
#         data["air_temperature_0_1km"],
#         data["air_temperature_1_5km"],
#         data["air_temperature_5_10km"],
#         data["dew_point"]
#     )
#     cur.execute(query, values)

# %%
# # Function to check if launch keys are generated
# def get_generated_launch_keys():
#     try:
#         query = "SELECT id FROM launch WHERE is_generated = TRUE"
#         cur.execute(query)
#         return cur.fetchall()
#     except psycopg2.Error as e:
#         print(f"Error retrieving launch keys: {e}")
#         conn.rollback()
#         return []

# %%
# # Check columns in the launch table
# # cur.execute("SELECT id FROM information_schema.columns WHERE table_name = 'launch'")
# # columns = cur.fetchall()
# # print(columns)
# # Retrieve all ids from the launch table

# # cur.execute("SELECT id FROM launch")
# # launch_keys = cur.fetchall()

# # # Generate and insert data for each launch key
# # start_date = datetime.datetime.now()
# # for (launch_key,) in launch_keys:
# #     data = generate_random_data()
# #     insert_data(data, start_date, launch_key)

# # cur.close()
# # conn.close()

# # # Retrieve all IDs from the launch table
# # cur.execute("SELECT id FROM launch")
# # launch_ids = cur.fetchall()

# # # Generate and insert data for each launch ID
# # for (launch_id,) in launch_ids:
# #     weather_data = generate_random_data()
# #     insert_data(launch_id, weather_data)

# # # Commit the transaction and close the connection
# # conn.commit()
# # cur.close()
# # conn.close()


# # Retrieve all IDs from the launch table
# cur.execute("SELECT id FROM launch")
# launch_ids = cur.fetchall()

# # Generate and insert data for each ID
# for (id,) in launch_ids:
#     weather_data = generate_random_data()
#     insert_data(id, weather_data)

# # Commit the transaction and close the connection
# conn.commit()
# cur.close()
# conn.close()

# %%
# def insert_data(launch_id, data):
#     query = """
#     INSERT INTO launch_weather (
#         launch_id,
#         timestamp,
#         surface_temperature,
#         surface_wind_speed,
#         surface_wind_direction,
#         surface_humidity,
#         precipitation_type,
#         precipitation_intensity,
#         visibility,
#         upper_wind_speed_0_1km,
#         upper_wind_speed_1_5km,
#         upper_wind_speed_5_10km,
#         upper_wind_direction_0_1km,
#         upper_wind_direction_1_5km,
#         upper_wind_direction_5_10km,
#         temperature_profile_0_1km,
#         temperature_profile_1_5km,
#         temperature_profile_5_10km,
#         humidity_profile_0_1km,
#         humidity_profile_1_5km,
#         humidity_profile_5_10km,
#         pressure_profile_0_1km,
#         pressure_profile_1_5km,
#         pressure_profile_5_10km,
#         turbulence_level_0_1km,
#         turbulence_level_1_5km,
#         turbulence_level_5_10km,
#         solar_radiation_levels,
#         geomagnetic_activity,
#         solar_flare_activity,
#         cosmic_ray_intensity,
#         lightning_frequency,
#         lightning_proximity,
#         cloud_base_altitude,
#         cloud_top_altitude,
#         cloud_thickness,
#         cloud_coverage_percentage,
#         sea_surface_temperature,
#         wave_height,
#         wave_direction,
#         current_speed,
#         current_direction,
#         pm2_5,
#         pm10,
#         co,
#         o3,
#         no2,
#         so2,
#         ground_temperature,
#         air_temperature_0_1km,
#         air_temperature_1_5km,
#         air_temperature_5_10km,
#         dew_point,
#         ground_moisture_level,
#         soil_temperature,
#         fog_presence_and_density
#     ) VALUES (
#         %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s
#     )
#     """
#     values = (
#         launch_id,
#         data["timestamp"],
#         data["weather_conditions"]["surface_temperature"],
#         data["weather_conditions"]["surface_wind_speed"],
#         data["weather_conditions"]["surface_wind_direction"],
#         data["weather_conditions"]["surface_humidity"],
#         data["weather_conditions"]["precipitation_type"],
#         data["weather_conditions"]["precipitation_intensity"],
#         data["weather_conditions"]["visibility"],
#         data["upper_atmosphere_conditions"]["upper_wind_speeds"]["0-1km"],
#         data["upper_atmosphere_conditions"]["upper_wind_speeds"]["1-5km"],
#         data["upper_atmosphere_conditions"]["upper_wind_speeds"]["5-10km"],
#         data["upper_atmosphere_conditions"]["upper_wind_directions"]["0-1km"],
#         data["upper_atmosphere_conditions"]["upper_wind_directions"]["1-5km"],
#         data["upper_atmosphere_conditions"]["upper_wind_directions"]["5-10km"],
#         data["upper_atmosphere_conditions"]["temperature_profiles"]["0-1km"],
#         data["upper_atmosphere_conditions"]["temperature_profiles"]["1-5km"],
#         data["upper_atmosphere_conditions"]["temperature_profiles"]["5-10km"],
#         data["upper_atmosphere_conditions"]["humidity_profiles"]["0-1km"],
#         data["upper_atmosphere_conditions"]["humidity_profiles"]["1-5km"],
#         data["upper_atmosphere_conditions"]["humidity_profiles"]["5-10km"],
#         data["upper_atmosphere_conditions"]["pressure_profiles"]["0-1km"],
#         data["upper_atmosphere_conditions"]["pressure_profiles"]["1-5km"],
#         data["upper_atmosphere_conditions"]["pressure_profiles"]["5-10km"],
#         data["upper_atmosphere_conditions"]["turbulence_levels"]["0-1km"],
#         data["upper_atmosphere_conditions"]["turbulence_levels"]["1-5km"],
#         data["upper_atmosphere_conditions"]["turbulence_levels"]["5-10km"],
#         data["solar_activity"]["solar_radiation_levels"],
#         data["solar_activity"]["geomagnetic_activity"],
#         data["solar_activity"]["solar_flare_activity"],
#         data["solar_activity"]["cosmic_ray_intensity"],
#         data["lightning_activity"]["lightning_frequency"],
#         data["lightning_activity"]["lightning_proximity"],
#         data["cloud_cover"]["cloud_base_altitude"],
#         data["cloud_cover"]["cloud_top_altitude"],
#         data["cloud_cover"]["cloud_thickness"],
#         data["cloud_cover"]["cloud_coverage_percentage"],
#         data["marine_conditions"]["sea_surface_temperature"],
#         data["marine_conditions"]["wave_height"],
#         data["marine_conditions"]["wave_direction"],
#         data["marine_conditions"]["current_speed"],
#         data["marine_conditions"]["current_direction"],
#         data["air_quality"]["pm2_5"],
#         data["air_quality"]["pm10"],
#         data["air_quality"]["co"],
#         data["air_quality"]["o3"],
#         data["air_quality"]["no2"],
#         data["air_quality"]["so2"],
#         data["thermal_conditions"]["ground_temperature"],
#         data["thermal_conditions"]["air_temperature_at_different_altitudes"]["0-1km"],
#         data["thermal_conditions"]["air_temperature_at_different_altitudes"]["1-5km"],
#         data["thermal_conditions"]["air_temperature_at_different_altitudes"]["5-10km"],
#         data["thermal_conditions"]["dew_point"],
#         data["launch_site_specific_conditions"]["ground_moisture_level"],
#         data["launch_site_specific_conditions"]["soil_temperature"],
#         data["launch_site_specific_conditions"]["fog_presence_and_density"]
#     )
#     cur.execute(query, values)

# %%
# # Function to insert data into the database
# def insert_data(id, data):
#     query = """
#     INSERT INTO launch_weather (
#         launch_id,
#         surface_temperature,
#         surface_wind_speed,
#         surface_wind_direction,
#         surface_humidity,
#         precipitation_type,
#         precipitation_intensity,
#         visibility,
#         upper_wind_speed_0_1km,
#         upper_wind_speed_1_5km,
#         upper_wind_speed_5_10km,
#         upper_wind_direction_0_1km,
#         upper_wind_direction_1_5km,
#         upper_wind_direction_5_10km,
#         temperature_profile_0_1km,
#         temperature_profile_1_5km,
#         temperature_profile_5_10km,
#         humidity_profile_0_1km,
#         humidity_profile_1_5km,
#         humidity_profile_5_10km,
#         pressure_profile_0_1km,
#         pressure_profile_1_5km,
#         pressure_profile_5_10km,
#         turbulence_level_0_1km,
#         turbulence_level_1_5km,
#         turbulence_level_5_10km,
#         solar_radiation_levels,
#         geomagnetic_activity,
#         solar_flare_activity,
#         cosmic_ray_intensity,
#         lightning_frequency,
#         lightning_proximity,
#         cloud_base_altitude,
#         cloud_top_altitude,
#         cloud_thickness,
#         cloud_coverage_percentage,
#         sea_surface_temperature,
#         wave_height,
#         wave_direction,
#         current_speed,
#         current_direction,
#         pm2_5,
#         pm10,
#         co,
#         o3,
#         no2,
#         so2,
#         ground_temperature,
#         air_temperature_0_1km,
#         air_temperature_1_5km,
#         air_temperature_5_10km,
#         dew_point,
#         ground_moisture_level,
#         soil_temperature,
#         fog_presence_and_density
#     ) VALUES (
#         %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s
#     )
#     """
#     values = (
#         id,
#         data["weather_conditions"]["surface_temperature"],
#         data["weather_conditions"]["surface_wind_speed"],
#         data["weather_conditions"]["surface_wind_direction"],
#         data["weather_conditions"]["surface_humidity"],
#         data["weather_conditions"]["precipitation_type"],
#         data["weather_conditions"]["precipitation_intensity"],
#         data["weather_conditions"]["visibility"],
#         data["upper_atmosphere_conditions"]["upper_wind_speeds"]["0-1km"],
#         data["upper_atmosphere_conditions"]["upper_wind_speeds"]["1-5km"],
#         data["upper_atmosphere_conditions"]["upper_wind_speeds"]["5-10km"],
#         data["upper_atmosphere_conditions"]["upper_wind_directions"]["0-1km"],
#         data["upper_atmosphere_conditions"]["upper_wind_directions"]["1-5km"],
#         data["upper_atmosphere_conditions"]["upper_wind_directions"]["5-10km"],
#         data["upper_atmosphere_conditions"]["temperature_profiles"]["0-1km"],
#         data["upper_atmosphere_conditions"]["temperature_profiles"]["1-5km"],
#         data["upper_atmosphere_conditions"]["temperature_profiles"]["5-10km"],
#         data["upper_atmosphere_conditions"]["humidity_profiles"]["0-1km"],
#         data["upper_atmosphere_conditions"]["humidity_profiles"]["1-5km"],
#         data["upper_atmosphere_conditions"]["humidity_profiles"]["5-10km"],
#         data["upper_atmosphere_conditions"]["pressure_profiles"]["0-1km"],
#         data["upper_atmosphere_conditions"]["pressure_profiles"]["1-5km"],
#         data["upper_atmosphere_conditions"]["pressure_profiles"]["5-10km"],
#         data["upper_atmosphere_conditions"]["turbulence_levels"]["0-1km"],
#         data["upper_atmosphere_conditions"]["turbulence_levels"]["1-5km"],
#         data["upper_atmosphere_conditions"]["turbulence_levels"]["5-10km"],
#         data["solar_activity"]["solar_radiation_levels"],
#         data["solar_activity"]["geomagnetic_activity"],
#         data["solar_activity"]["solar_flare_activity"],
#         data["solar_activity"]["cosmic_ray_intensity"],
#         data["lightning_activity"]["lightning_frequency"],
#         data["lightning_activity"]["lightning_proximity"],
#         data["cloud_cover"]["cloud_base_altitude"],
#         data["cloud_cover"]["cloud_top_altitude"],
#         data["cloud_cover"]["cloud_thickness"],
#         data["cloud_cover"]["cloud_coverage_percentage"],
#         data["marine_conditions"]["sea_surface_temperature"],
#         data["marine_conditions"]["wave_height"],
#         data["marine_conditions"]["wave_direction"],
#         data["marine_conditions"]["current_speed"],
#         data["marine_conditions"]["current_direction"],
#         data["air_quality"]["pm2_5"],
#         data["air_quality"]["pm10"],
#         data["air_quality"]["co"],
#         data["air_quality"]["o3"],
#         data["air_quality"]["no2"],
#         data["air_quality"]["so2"],
#         data["thermal_conditions"]["ground_temperature"],
#         data["thermal_conditions"]["air_temperature_at_different_altitudes"]["0-1km"],
#         data["thermal_conditions"]["air_temperature_at_different_altitudes"]["1-5km"],
#         data["thermal_conditions"]["air_temperature_at_different_altitudes"]["5-10km"],
#         data["thermal_conditions"]["dew_point"],
#         data["launch_site_specific_conditions"]["ground_moisture_level"],
#         data["launch_site_specific_conditions"]["soil_temperature"],
#         data["launch_site_specific_conditions"]["fog_presence_and_density"]
#     )
#     cur.execute(query, values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 130
#     128 for (id,) in launch_ids:
#     129     weather_data = generate_random_data(base_date)
# --> 130     insert_data(id, weather_data)
#     132 # Commit the transaction and close the connection
#     133 conn.commit()
#
# Cell In[10], line 66, in insert_data(data, timestamp)
#       2 def insert_data(data, timestamp):
#       3     query = """
#       4     INSERT INTO launch_weather (
#       5         timestamp,
#    (...)
#      62     )
#      63     """
#      64     values = (
#      65         timestamp,
# ---> 66         data["weather_conditions"]["surface_temperature"],
#      67         data["weather_conditions"]["surface_wind_speed"],
#      68         data["weather_conditions"]["surface_wind_direction"],
#      69         data["weather_conditions"]["surface_humidity"],
#      70         data["weather_conditions"]["precipitation_type"],
#      71         data["weather_conditions"]["precipitation_intensity"],
#      72         data["weather_conditions"]["visibility"],
#      73         data["upper_atmosphere_conditions"]["upper_wind_speeds"]["0-1km"],
#      74         data["upper_atmosphere_conditions"]["upper_wind_speeds"]["1-5km"],
#      75         data["upper_atmosphere_conditions"]["upper_wind_speeds"]["5-10km"],
#      76         data["upper_atmosphere_conditions"]["upper_wind_directions"]["0-1km"],
#      77         data["upper_atmosphere_conditions"]["upper_wind_directions"]["1-5km"],
#      78         data["upper_atmosphere_conditions"]["upper_wind_directions"]["5-10km"],
#      79         data["upper_atmosphere_conditions"]["temperature_profiles"]["0-1km"],
#      80         data["upper_atmosphere_conditions"]["temperature_profiles"]["1-5km"],
#      81         data["upper_atmosphere_conditions"]["temperature_profiles"]["5-10km"],
#      82         data["upper_atmosphere_conditions"]["humidity_profiles"]["0-1km"],
#      83         data["upper_atmosphere_conditions"]["humidity_profiles"]["1-5km"],
#      84         data["upper_atmosphere_conditions"]["humidity_profiles"]["5-10km"],
#      85         data["upper_atmosphere_conditions"]["pressure_profiles"]["0-1km"],
#      86         data["upper_atmosphere_conditions"]["pressure_profiles"]["1-5km"],
#      87         data["upper_atmosphere_conditions"]["pressure_profiles"]["5-10km"],
#      88         data["upper_atmosphere_conditions"]["turbulence_levels"]["0-1km"],
#      89         data["upper_atmosphere_conditions"]["turbulence_levels"]["1-5km"],
#      90         data["upper_atmosphere_conditions"]["turbulence_levels"]["5-10km"],
#      91         data["solar_activity"]["solar_radiation_levels"],
#      92         data["solar_activity"]["geomagnetic_activity"],
#      93         data["solar_activity"]["solar_flare_activity"],
#      94         data["solar_activity"]["cosmic_ray_intensity"],
#      95         data["lightning_activity"]["lightning_frequency"],
#      96         data["lightning_activity"]["lightning_proximity"],
#      97         data["cloud_cover"]["cloud_base_altitude"],
#      98         data["cloud_cover"]["cloud_top_altitude"],
#      99         data["cloud_cover"]["cloud_thickness"],
#     100         data["cloud_cover"]["cloud_coverage_percentage"],
#     101         data["marine_conditions"]["sea_surface_temperature"],
#     102         data["marine_conditions"]["wave_height"],
#     103         data["marine_conditions"]["wave_direction"],
#     104         data["marine_conditions"]["current_speed"],
#     105         data["marine_conditions"]["current_direction"],
#     106         data["air_quality"]["pm2_5"],
#     107         data["air_quality"]["pm10"],
#     108         data["air_quality"]["co"],
#     109         data["air_quality"]["o3"],
#     110         data["air_quality"]["no2"],
#     111         data["air_quality"]["so2"],
#     112         data["thermal_conditions"]["ground_temperature"],
#     113         data["thermal_conditions"]["air_temperature_at_different_altitudes"]["0-1km"],
#     114         data["thermal_conditions"]["air_temperature_at_different_altitudes"]["1-5km"],
#     115         data["thermal_conditions"]["air_temperature_at_different_altitudes"]["5-10km"],
#     116         data["thermal_conditions"]["dew_point"],
#     117         data["launch_site_specific_conditions"]["ground_moisture_level"],
#     118         data["launch_site_specific_conditions"]["soil_temperature"],
#     119         data["launch_site_specific_conditions"]["fog_presence_and_density"]
#     120     )
#     121     cur.execute(query, values)
#
# TypeError: string indices must be integers, not 'str'

# %%
# # Generate and insert data for each generated launch key
# generated_launch_keys = get_generated_launch_keys()
# start_date = datetime.datetime.now()

# %%
# for launch_key_tuple in generated_launch_keys:
#     launch_key = launch_key_tuple[0]
#     for day in range(7):
#         for minute in range(24 * 60):
#             timestamp = start_date + datetime.timedelta(days=day, minutes=minute)
#             data = generate_random_data()
#             insert_data(data, timestamp, launch_key)

# %%
# # Generate and insert data for 7 days, 24 hours each
# start_date = datetime.datetime(2023, 7, 1)
# for day in range(7):
#     for hour in range(24):
#         timestamp = start_date + datetime.timedelta(days=day, hours=hour)
#         data = generate_random_data()
#         insert_data(data, timestamp)

# %%
# # Close the database connection
# cur.close()
# conn.close()
